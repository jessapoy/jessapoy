# %% [markdown]
# <a href="https://colab.research.google.com/github/jessapoy/jessapoy/blob/main/Nourishment_by_Numbers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_excel("Food Count with Supplemental and Asterisk -  02.27.xlsx")

# %%
df.head()
# Out:
#         Date Count Day of Week Weekend  max_temp_f  min_temp_f  \
# 0 2023-10-31   607     Tuesday       N        38.0        21.0
# 1 2023-06-30     *      Friday       N        85.0        68.0
# 2 2023-08-31   541    Thursday       N        83.0        59.0
# 3 2024-01-31     *   Wednesday       N        56.0        24.0
# 4 2021-09-30   315    Thursday       N        86.0        65.0
#
#    max_dewpoint_f  min_dewpoint_f  precip_in  avg_wind_speed_kts  ...  \
# 0            20.0            16.0     0.0001           15.120187  ...
# 1            71.1            64.0     0.3900            4.692471  ...
# 2            56.0            49.0     0.0000            8.255275  ...
# 3            40.0            23.0     0.0000            5.561448  ...
# 4            66.0            62.1     0.0300            6.008362  ...
#
#    max_wind_gust_kts  srad_mj  climo_high_f  climo_low_f  climo_precip_in  \
# 0          38.234955        *          55.8         36.6             0.08
# ...

# %%
df.describe()
# Out:
#                       Date   max_temp_f   min_temp_f  max_dewpoint_f  \
# count                 1311  1311.000000  1311.000000     1311.000000
# mean   2023-04-17 00:00:00    63.397483    43.100686       46.058734
# min    2021-07-01 00:00:00    -7.000000   -17.000000      -17.000000
# 25%    2022-05-24 12:00:00    46.000000    28.000000       31.000000
# 50%    2023-04-17 00:00:00    68.000000    44.000000       46.400000
# 75%    2024-03-09 12:00:00    82.000000    62.000000       63.000000
# max    2025-01-31 00:00:00   100.000000    80.000000       80.000000
# std                    NaN    21.968904    20.615875       19.254610
#
#        min_dewpoint_f    precip_in  avg_wind_speed_kts  avg_wind_drct  \
# count     1311.000000  1311.000000         1311.000000    1311.000000
# mean        35.340503     0.083646            8.350347     198.203984
# min        -25.000000     0.000000            1.390362       2.161512
# ...
